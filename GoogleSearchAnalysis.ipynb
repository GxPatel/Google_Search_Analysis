# %% [markdown]
# ## Google Search Analysis with Python

# %% [markdown]
# ### Introduction
#
# Approximately 3.5 billion searches are performed on Google daily, which means that approximately 40,000 searches are performed every second on Google. So Google search is a great use case for analyzing data based on search queries.
#
# With that in mind, in this project, I will walk you through the task of Google Search Analysis with $Python$.

# %% [markdown]
# Google doesn’t give much access to the data about daily search queries, but another application of google known as Google Trends can be used for the task of Google search analysis. Google Trends provides an API that can be used to analyze the daily searches on Google.

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt


trends = TrendReq()

# %% [markdown]
# Here, I will be analyzing the Google search trends on the queries based on “Artificial Intelligence” by creating a DataFrame of the top 10 countries which search for “Artificial Intelligence” on Google.

# %%
trends.build_payload(kw_list=["Artificial Intelligence"])
data = trends.interest_by_region()
data = data.sort_values(by="Artificial Intelligence", ascending=False)
data = data.head(10)
print(data)
# Out:
#                       Artificial Intelligence
# geoName
# Ethiopia                                  100
# Zimbabwe                                   62
# Pakistan                                   50
# China                                      45
# India                                      43
# Kenya                                      38
# United Arab Emirates                       36
# Nigeria                                    35
# Nepal                                      34
# Singapore                                  32

# %% [markdown]
# So, according to the above results, the search queries based on “Artificial Intelligence” are mostly done in Ethiopia. We can also visualize this data using a bar chart.

# %%
data.reset_index().plot(x="geoName", 
                        y="Artificial Intelligence", 
                        figsize=(15,12), kind="bar")
plt.style.use('fivethirtyeight')
plt.show()

# %% [markdown]
# So, as we all know that Machine Learning has been the focus of so many companies and students for the last 3-4 years, so let’s have a look at the trend of searches to see how the total search queries based on “Artificial Intelligence” increased or decreased on Google.

# %%
data = TrendReq(hl='en-US', tz=360)
data.build_payload(kw_list=['Artificial Intelligence'])
data = data.interest_over_time()
fig, ax = plt.subplots(figsize=(15, 12))
data['Artificial Intelligence'].plot()
plt.style.use('fivethirtyeight')
plt.title('Total Google Searches for Artificial Intelligence', 
          fontweight='bold')
plt.xlabel('Year')
plt.ylabel('Total Count')
plt.show()

# %% [markdown]
# ## Conclusion
#
# So we can see a huge increase in the searches about “Artificial Intelligence” on Google in 2023. This is how we can analyze Google searches based on any other keywords.
#
# A business can also perform Google search analysis to understand what people are looking for on Google at any given time.
